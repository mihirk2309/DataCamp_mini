# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.DataFrame(pd.read_csv("2015-building-energy-benchmarking.csv"))
df = pd.DataFrame(pd.read_csv("2016-building-energy-benchmarking.csv"))

# %%
df1.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
# 3              5      2015  NonResidential               Hotel
# 4              8      2015  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...                    7
# 1  {'latitude': '47.61310583', 'longitude': '-122...                    7
# ...

# %%
df.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)  \
# 0                    0659000030  ...      1.156514e+06         3946027.0
# ...

# %%
frames = [df1, df]
result = pd.concat(frames, axis=1)
result.head()
#df1.describe()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0            1.0    2015.0  NonResidential               Hotel
# 1            2.0    2015.0  NonResidential               Hotel
# 2            3.0    2015.0  NonResidential               Hotel
# 3            5.0    2015.0  NonResidential               Hotel
# 4            8.0    2015.0  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...                  7.0
# 1  {'latitude': '47.61310583', 'longitude': '-122...                  7.0
# ...

# %%
df.drop(['DataYear','PropertyName', 'TaxParcelIdentificationNumber', 
       'CouncilDistrictCode','DefaultData','ListOfAllPropertyUseTypes','LargestPropertyUseType','LargestPropertyUseTypeGFA','SecondLargestPropertyUseType',
         'SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseType','ThirdLargestPropertyUseTypeGFA','Comments'  
       ,'Neighborhood', 'YearsENERGYSTARCertified', 'ZipCode','Address','City','State','Outlier'], axis=1).head()
# Out:
#    OSEBuildingID    BuildingType PrimaryPropertyType  Latitude  Longitude  \
# 0              1  NonResidential               Hotel  47.61220 -122.33799
# 1              2  NonResidential               Hotel  47.61317 -122.33393
# 2              3  NonResidential               Hotel  47.61393 -122.33810
# 3              5  NonResidential               Hotel  47.61412 -122.33664
# 4              8  NonResidential               Hotel  47.61375 -122.34047
#
#    YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0       1927                1.0              12             88434
# 1       1996                1.0              11            103566
# 2       1969                1.0              41            956110
# 3       1926                1.0              10             61320
# 4       1980                1.0              18            175580
#
#    PropertyGFAParking  ...  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  \
# ...

# %%
df1.drop(['DataYear','PropertyName', 'TaxParcelIdentificationNumber', 
       'CouncilDistrictCode','DefaultData', 'Comment', 'ComplianceStatus','ListOfAllPropertyUseTypes','LargestPropertyUseType','LargestPropertyUseTypeGFA','SecondLargestPropertyUseType',
         'SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseType','ThirdLargestPropertyUseTypeGFA', 
       '2010 Census Tracts','Seattle Police Department Micro Community Policing Plan Areas',
       'City Council Districts','Neighborhood', 'YearsENERGYSTARCertified','SPD Beats', 'Zip Codes','Outlier'],axis=1).head()
# Out:
#    OSEBuildingID    BuildingType PrimaryPropertyType  \
# 0              1  NonResidential               Hotel
# 1              2  NonResidential               Hotel
# 2              3  NonResidential               Hotel
# 3              5  NonResidential               Hotel
# 4              8  NonResidential               Hotel
#
#                                             Location  YearBuilt  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...       1927
# 1  {'latitude': '47.61310583', 'longitude': '-122...       1996
# 2  {'latitude': '47.61334897', 'longitude': '-122...       1969
# 3  {'latitude': '47.61421585', 'longitude': '-122...       1926
# 4  {'latitude': '47.6137544', 'longitude': '-122....       1980
#
#    NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0                  1            12.0             88434                   0
# 1                  1            11.0            103566               15064
# ...

# %%
df_grp=df.groupby(['PrimaryPropertyType', 'PropertyName','ENERGYSTARScore','DataYear'], as_index=False).mean()

# %%
df_grp
# Out:
#       PrimaryPropertyType                               PropertyName  \
# 0     Distribution Center                                     124N35
# 1     Distribution Center                                       2900
# 2     Distribution Center                                       3223
# 3     Distribution Center                                       3317
# 4     Distribution Center             3420/3430 E. Marginal Way Whse
# ...                   ...                                        ...
# 2528     Worship Facility  University Temple United Methodist Church
# 2529     Worship Facility                University Unitarian Church
# 2530     Worship Facility              West Side Presbyterian Church
# 2531     Worship Facility                Westood Christian Community
# 2532     Worship Facility             Woodland Park Methodist Church
#
#       ENERGYSTARScore  DataYear  OSEBuildingID  ZipCode  CouncilDistrictCode  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
# ...

# %%
df=df.reindex(sorted(df.columns), axis=1)

# %%
df.columns
# Out:
# Index(['Address', 'BuildingType', 'City', 'Comments', 'ComplianceStatus',
#        'CouncilDistrictCode', 'DataYear', 'DefaultData', 'ENERGYSTARScore',
#        'Electricity(kBtu)', 'Electricity(kWh)', 'GHGEmissionsIntensity',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA', 'Latitude',
#        'ListOfAllPropertyUseTypes', 'Longitude', 'NaturalGas(kBtu)',
#        'NaturalGas(therms)', 'Neighborhood', 'NumberofBuildings',
#        'NumberofFloors', 'OSEBuildingID', 'Outlier', 'PrimaryPropertyType',
#        'PropertyGFABuilding(s)', 'PropertyGFAParking', 'PropertyGFATotal',
#        'PropertyName', 'SecondLargestPropertyUseType',
#        'SecondLargestPropertyUseTypeGFA', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)',
#        'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)', 'State', 'SteamUse(kBtu)',
#        'TaxParcelIdentificationNumber', 'ThirdLargestPropertyUseType',
# ...

# %%
df.plot(x="NaturalGas(kBtu)", y="TotalGHGEmissions")

# %%
df1["GHGEmissionsIntensity(kgCO2e/ft2)"]=(df1["GHGEmissionsIntensity(kgCO2e/ft2)"])/df1["GHGEmissionsIntensity(kgCO2e/ft2)"].max()
plt.figure(figsize=(15,8))
sns.lineplot(x='BuildingType',y='GHGEmissionsIntensity(kgCO2e/ft2)', data=df1)

# %%
sns.jointplot(df1.loc[:,'ENERGYSTARScore'], df1.loc[:,'GHGEmissions(MetricTonsCO2e)'], kind="regg", color="#ce1414")

# %%
sns.jointplot(df1.loc[:,'ENERGYSTARScore'], df1.loc[:,'SiteEnergyUse(kBtu)'], kind="regg", color="#ce1414")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
# ...

# %%
df1.describe()
df1.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
df.describe()
# Out:
#        Comments  CouncilDistrictCode  DataYear  ENERGYSTARScore  \
# count       0.0          3376.000000    3376.0      2533.000000
# mean        NaN             4.439277    2016.0        67.918674
# std         NaN             2.120625       0.0        26.873271
# min         NaN             1.000000    2016.0         1.000000
# 25%         NaN             3.000000    2016.0        53.000000
# 50%         NaN             4.000000    2016.0        75.000000
# 75%         NaN             7.000000    2016.0        90.000000
# max         NaN             7.000000    2016.0       100.000000
#
#        Electricity(kBtu)  Electricity(kWh)  GHGEmissionsIntensity  \
# count       3.367000e+03      3.367000e+03            3367.000000
# mean        3.707612e+06      1.086639e+06               1.175916
# std         1.485066e+07      4.352478e+06               1.821452
# min        -1.154170e+05     -3.382680e+04              -0.020000
# ...

# %%
print(df1.shape)
print(df.shape)
# Out:
# (3340, 47)
# (3376, 46)

# %%
df.corr()
# Out:
#                                  Comments  CouncilDistrictCode  DataYear  \
# Comments                              NaN                  NaN       NaN
# CouncilDistrictCode                   NaN             1.000000       NaN
# DataYear                              NaN                  NaN       NaN
# DefaultData                           NaN            -0.084379       NaN
# ENERGYSTARScore                       NaN             0.059524       NaN
# Electricity(kBtu)                     NaN             0.056176       NaN
# Electricity(kWh)                      NaN             0.056176       NaN
# GHGEmissionsIntensity                 NaN             0.003274       NaN
# LargestPropertyUseTypeGFA             NaN             0.067790       NaN
# Latitude                              NaN             0.489348       NaN
# Longitude                             NaN            -0.265482       NaN
# NaturalGas(kBtu)                      NaN             0.003467       NaN
# ...

# %%
df1.corr()
# Out:
#                                                     OSEBuildingID  DataYear  \
# OSEBuildingID                                            1.000000       NaN
# DataYear                                                      NaN       NaN
# CouncilDistrictCode                                     -0.092519       NaN
# YearBuilt                                                0.134578       NaN
# NumberofBuildings                                       -0.000676       NaN
# NumberofFloors                                          -0.113519       NaN
# PropertyGFATotal                                        -0.268611       NaN
# PropertyGFAParking                                      -0.179414       NaN
# PropertyGFABuilding(s)                                  -0.261334       NaN
# LargestPropertyUseTypeGFA                               -0.252482       NaN
# SecondLargestPropertyUseTypeGFA                         -0.223600       NaN
# ...

# %%
df1['GHGEmissions(MetricTonsCO2e)'].fillna(df1['GHGEmissions(MetricTonsCO2e)'].mean(), inplace=True)
df1['ENERGYSTARScore'].fillna(df1['ENERGYSTARScore'].mean(), inplace=True)
df1["SiteEnergyUseWN(kBtu)"].fillna(df1["SiteEnergyUseWN(kBtu)"].mean(), inplace=True)
df1["Electricity(kBtu)"].fillna(df1["Electricity(kBtu)"].mean(), inplace=True)
df['ENERGYSTARScore'].fillna(df['ENERGYSTARScore'].mean(), inplace=True)
df['TotalGHGEmissions'].fillna(df['TotalGHGEmissions'].mean(), inplace=True)
df['Electricity(kWh)'].fillna(df['Electricity(kWh)'].mean(), inplace=True)
df['GHGEmissionsIntensity'].fillna(df['GHGEmissionsIntensity'].mean(), inplace=True)

# %%
# plt.figure(figsize=(10,7))
# w=0.4
# df2 = df.groupby(['BuildingType']).mean()
# df3 = df1.groupby(['BuildingType']).mean()
# x = df2.index
# bar1 = np.arange(len(x))
# bar2 = [i+w for i in bar1]
# plt.bar(bar1,df['TotalGHGEmissions'],w,label='2015')
# plt.bar(bar2,df1['GHGEmissions(MetricTonsCO2e)'],w,label='2016')
# plt.xticks(bar1,x)
# plt.xticks(rotation=90)
# plt.legend()
# plt.ylabel("GHGEmissions(MetricTonsCO2e)")
# plt.xlabel("BuildingType")
# plt.title("bar plot of building type and GHE emmision 2015 and 2016")
# plt.show()

# %%
df1.columns
#df1['BuildingType'].head()
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
plt.figure(figsize=(7,5))
sns.barplot(x='BuildingType',y='GHGEmissions(MetricTonsCO2e)', data=df1, palette = 'icefire')
#sns.barplot(data=df_2016,x='BuildingType',y='GHGEmissions(MetricTonsCO2e)')
plt.xticks(rotation=90)
plt.ylabel("GHGEmissions(MetricTonsCO2e)")
plt.xlabel("BuildingType")
plt.title("bar plot of building type and GHEemmision 2015 ")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.barplot(data=df1,x='BuildingType',y='GHGEmissionsIntensity(kgCO2e/ft2)',)
plt.xticks(rotation=90)
plt.ylabel("GHGEmissionsIntensity(kgCO2e/ft2)")
plt.xlabel("BuildingType")
plt.title("bar plot of building type and GHE emmision intensity  2015 ")
plt.show()

# %%
print(df1['PrimaryPropertyType'].value_counts())
print(df['PrimaryPropertyType'].value_counts())
# Out:
# Low-Rise Multifamily           998
# Mid-Rise Multifamily           539
# Small- and Mid-Sized Office    297
# Other                          258
# Non-Refrigerated Warehouse     187
# Large Office                   171
# K-12 School                    136
# Mixed Use Property             126
# High-Rise Multifamily          103
# Retail Store                   100
# Hotel                           73
# Worship Facility                72
# Distribution Center\n           51
# Medical Office                  43
# Senior Care Community           43
# Supermarket/Grocery Store       36
# Self-Storage Facility\n         27
# College/University              22
# Residence Hall/Dormitory        15
# Refrigerated Warehouse          13
# Restaurant\n                    11
# Hospital                        10
# SPS-District K-12                4
# Distribution Center              2
# Laboratory                       1
# Restaurant                       1
# Self-Storage Facility            1
# ...

# %%
plt.figure(figsize=(9,7))
sns.barplot(data=df1,x='PrimaryPropertyType',y='GHGEmissionsIntensity(kgCO2e/ft2)')
plt.xticks(rotation=90)
plt.ylabel("GHGEmissionsIntensity(kgCO2e/ft2)")
plt.xlabel("PrimaryPropertyType")
plt.title("bar plot of PrimaryPropertyType and co2 emmision intensity  2015 ")
plt.show()

# %%
plt.figure(figsize=(9,7))
sns.barplot(data=df,x='PrimaryPropertyType',y='TotalGHGEmissions')
plt.xticks(rotation=90)
plt.ylabel("GHGEmissionsIntensity(kgCO2e/ft2)")
plt.xlabel("PrimaryPropertyType")
plt.title("bar plot of PrimaryPropertyType and co2 emmision intensity  2016")
plt.show()

# %%
print(df.isnull().values.sum())
# Out:
# 19082

# %%
sns.jointplot(df.loc[:,'SiteEnergyUseWN(kBtu)'], df.loc[:,'TotalGHGEmissions'], kind="regg", color="#ce1414")

# %%
plt.scatter(df1["PropertyGFATotal"],df1["GHGEmissions(MetricTonsCO2e)"],  color='green')
plt.xlabel("PropertyGFATotal")
plt.ylabel("GHGEmissions(MetricTonsCO2e)")
plt.show()

# %%
# groupby analysis 
display(df['BuildingType'].value_counts())
df_BuildingType = df.groupby('BuildingType', axis=0).sum()

# note: the output of the groupby method is a `groupby' object. 
# we can not use it further until we apply a function (eg .sum())
print(type(df.groupby('BuildingType', axis=0)))

from IPython.display import display
    
df_BuildingType.head(10)
# Out:
# NonResidential          1460
# Multifamily LR (1-4)    1018
# Multifamily MR (5-9)     580
# Multifamily HR (10+)     110
# SPS-District K-12         98
# Nonresidential COS        85
# Campus                    24
# Nonresidential WA          1
# Name: BuildingType, dtype: int64
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#                       Comments  CouncilDistrictCode  DataYear  DefaultData  \
# BuildingType
# Campus                     0.0                   96     48384          0.0
# Multifamily HR (10+)       0.0                  639    221760          1.0
# Multifamily LR (1-4)       0.0                 4352   2052288         16.0
# Multifamily MR (5-9)       0.0                 2729   1169280          8.0
# NonResidential             0.0                 6458   2943360         10.0
# Nonresidential COS         0.0                  366    171360          3.0
# Nonresidential WA          0.0                    4      2016          0.0
# ...

# %%
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

# %%
plt.scatter(df["Electricity(kWh)"], df["TotalGHGEmissions"],  color='blue')
plt.xlabel("Electricity(kWh)")
plt.ylabel("TotalGHGEmissions")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(df[['Electricity(kWh)']])
train_y = np.asanyarray(df[['TotalGHGEmissions']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[8.55588655e-05]]
# Intercept:  [26.75237368]

# %%
plt.scatter(df["Electricity(kWh)"], df["TotalGHGEmissions"],  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Electricity(kWh)")
plt.ylabel("TotalGHGEmissions")
plt.show()

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(df[['Electricity(kWh)']])
test_y = np.asanyarray(df[['TotalGHGEmissions']])
test_y_hat = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_hat , test_y) )
# Out:
# Mean absolute error: 94.70
# Residual sum of squares (MSE): 151214.30
# R2-score: -0.09

# %%
regr = linear_model.LinearRegression()
train_x = np.asanyarray(df[['ENERGYSTARScore']])
train_y = np.asanyarray(df[['GHGEmissionsIntensity']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[-0.01488181]]
# Intercept:  [2.1866693]

# %%
plt.scatter(df["ENERGYSTARScore"], df["GHGEmissionsIntensity"],  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("ENERGYSTARScore")
plt.ylabel("GHGEmissionsIntensity")
plt.show()

# %%
test_x = np.asanyarray(df[['ENERGYSTARScore']])
test_y = np.asanyarray(df[['GHGEmissionsIntensity']])
test_y_hat = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_hat , test_y) )
# Out:
# Mean absolute error: 1.01
# Residual sum of squares (MSE): 3.19
# R2-score: -25.58

# %%
from sklearn import linear_model

X=df1[["ENERGYSTARScore","Electricity(kBtu)","SiteEnergyUseWN(kBtu)"]]
y=df1['GHGEmissions(MetricTonsCO2e)']

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(X, y, test_size= 0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression  
regressor= LinearRegression()  
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= regressor.predict(x_test)

print('Train Score: ', regressor.score(x_train, y_train))  
print('Test Score: ', regressor.score(x_test, y_test))
# Out:
# Train Score:  0.9305997815564088
# Test Score:  0.9300332783616636
